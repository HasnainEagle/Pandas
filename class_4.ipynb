# %%
# Important DataFrame Methods

# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv("ipl-matches.csv")

# %%
# value_counts(Series and DataFrame)

# %%
# find which player has won most potm (in finals and qualifiers)

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl[~ipl["MatchNumber"].str.isdigit()]["Player_of_Match"].value_counts()
# Out:
# Player_of_Match
# KA Pollard           3
# F du Plessis         3
# SK Raina             3
# A Kumble             2
# MK Pandey            2
# YK Pathan            2
# M Vijay              2
# JJ Bumrah            2
# AB de Villiers       2
# SR Watson            2
# HH Pandya            1
# Harbhajan Singh      1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# MS Bisla             1
# BJ Hodge             1
# MEK Hussey           1
# MS Dhoni             1
# CH Gayle             1
# MM Patel             1
# DE Bollinger         1
# AC Gilchrist         1
# RG Sharma            1
# DA Warner            1
# MC Henriques         1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# ...

# %%
# Toss Decision plot

# %%
ipl["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played

# %%
no_of_matches_each_team_played = (ipl["Team2"].value_counts() +  ipl["Team1"].value_counts()).sort_values(ascending=False)
no_of_matches_each_team_played.plot(kind="bar",color=["orange","pink","red"])
# Out:
# <Axes: >

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

# students

# %%
# sort_values(series and DataFrame)

# %%
# sort one column
students.sort_values("name",ascending=False,na_position="first",inplace=True)

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
# sort multiple columns 
movies = pd.read_csv("movies.csv")

# %%
movies.sort_values(["year_of_release","title_x"],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rank(Series)

# %%
batsman_runs = pd.read_csv("batsman_runs_ipl.csv")
batsman_runs
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman_runs["Ranking"] = batsman_runs["batsman_run"].rank(ascending=False)
batsman_runs.sort_values("Ranking",inplace=True)
batsman_runs
# Out:
#            batter  batsman_run  Ranking
# 569       V Kohli         6634      1.0
# 462      S Dhawan         6244      2.0
# 130     DA Warner         5883      3.0
# 430     RG Sharma         5881      4.0
# 493      SK Raina         5536      5.0
# ..            ...          ...      ...
# 512   SS Cottrell            0    594.0
# 466     S Kaushik            0    594.0
# 203     IC Pandey            0    594.0
# 467       S Ladda            0    594.0
# 468  S Lamichhane            0    594.0
#
# [605 rows x 3 columns]

# %%
# sort_index(Series and DataFrame)

# %%
batsman_runs.set_index('batter',inplace=True)
batsman_runs
# Out:
#               batsman_run  Ranking
# batter
# V Kohli              6634      1.0
# S Dhawan             6244      2.0
# DA Warner            5883      3.0
# RG Sharma            5881      4.0
# SK Raina             5536      5.0
# ...                   ...      ...
# SS Cottrell             0    594.0
# S Kaushik               0    594.0
# IC Pandey               0    594.0
# S Ladda                 0    594.0
# S Lamichhane            0    594.0
#
# [605 rows x 2 columns]

# %%
# reset_index(Series and DataFrame)

# %%
# how to replace existing index without lossing
# first reset
# second set_index
batsman_runs.reset_index(inplace=True)  
batsman_runs.set_index("Ranking",inplace=True)
batsman_runs
# Out:
#                batter  batsman_run
# Ranking
# 1.0           V Kohli         6634
# 2.0          S Dhawan         6244
# 3.0         DA Warner         5883
# 4.0         RG Sharma         5881
# 5.0          SK Raina         5536
# ...               ...          ...
# 594.0     SS Cottrell            0
# 594.0       S Kaushik            0
# 594.0       IC Pandey            0
# 594.0         S Ladda            0
# 594.0    S Lamichhane            0
#
# [605 rows x 2 columns]

# %%
# Series to DataFrame (using DataFrame)

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# Series ko DataFrame ma convert karna ka liya hum reset_index bhi use karsakta han
marks_series.reset_index()
type(marks_series.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
# rename (DataFrame) --->index
# with the help of rename we also change the name of index

# %%
movies.set_index("title_x",inplace=True)

# %%
movies.rename(columns={"imdb_id":"imdb","poster_path":"Link"},inplace=True)
movies.head(2)
# Out:
#                 imdb                                               Link  \
# title_x
# Uri        tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion  tt9472208                                                NaN
#
#                                                    wiki_link  \
# title_x
# Uri        https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Battalion        https://en.wikipedia.org/wiki/Battalion_609
#
#                             title_y            original_title  is_adult  \
# title_x
# Uri        Uri: The Surgical Strike  Uri: The Surgical Strike         0
# Battalion             Battalion 609             Battalion 609         0
#
#            year_of_release runtime            genres  imdb_rating  imdb_votes  \
# title_x
# Uri                   2019     138  Action|Drama|War          8.4       35112
# Battalion             2019     131               War          4.1          73
#
#                                                        story  \
# ...

# %%
movies.rename(index={"Uri: The Surgical Strike":"Uri","Battalion 609":"Battalion"},inplace=True)
movies.head(2)
# Out:
#                 imdb                                               Link  \
# title_x
# Uri        tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion  tt9472208                                                NaN
#
#                                                    wiki_link  \
# title_x
# Uri        https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# Battalion        https://en.wikipedia.org/wiki/Battalion_609
#
#                             title_y            original_title  is_adult  \
# title_x
# Uri        Uri: The Surgical Strike  Uri: The Surgical Strike         0
# Battalion             Battalion 609             Battalion 609         0
#
#            year_of_release runtime            genres  imdb_rating  imdb_votes  \
# title_x
# Uri                   2019     138  Action|Drama|War          8.4       35112
# Battalion             2019     131               War          4.1          73
#
#                                                        story  \
# ...

# %%
# unique(Series)
# unique count the missing value(nan)

# %%
temp = pd.Series([1,1,1,1,1,1,2,3,4,4,3,2,5,5,6,6,np.nan,np.nan])
temp.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6., nan])

# %%
# how many unique values in temp(we use the len or nunique method)
len(temp.unique())
# Out:
# 6

# %%
# nunique() method ----> doesnot count missing(nan) values --->dropna parameter

# %%
# how many seasons happened till now in ipl
ipl["Season"].nunique()
# Out:
# 15

# %%
# temp.nunique(dropna = False) --> to consider missing values use dropna parameter
temp.nunique()
# Out:
# 6

# %%
# Note:
# unique count karta ha missing values 
# nunique count nahi karta ha missing values ko

# %%
# isnull(Series + DataFrame)

# %%
# Series
students["name"][students["name"].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
# DataFrame
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 3   True     True    True   True     True
# 5   True    False   False  False    False
# 7   True     True   False  False    False
# 9   True    False    True   True     True
# 2  False    False   False  False    False
# 6  False    False   False  False    False
# 0  False    False   False  False    False
# 4  False     True   False  False    False
# 1  False    False   False  False    False
# 8  False     True   False  False     True

# %%
# notnull(Series + DataFrame)

# %%
# Series
students["name"][students["name"].notnull()]
# Out:
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
# DataFrame
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 3  False    False   False  False    False
# 5  False     True    True   True     True
# 7  False    False    True   True     True
# 9  False     True   False  False    False
# 2   True     True    True   True     True
# 6   True     True    True   True     True
# 0   True     True    True   True     True
# 4   True    False    True   True     True
# 1   True     True    True   True     True
# 8   True    False    True   True    False

# %%
# hasnans(Series)
# ya hamma batata ha ka hammara column ma koi missing value ha ya nahi

# %%
students["name"].hasnans
# Out:
# True

# %%
# dropna(Series+DataFrame) -----> how parameter ---> works like or
# dropna aik permanent operation nahi ha hamma inplace use karna hogha permanent changes karna ka liya .

# %%
# Series
students["name"].dropna()
# students
# Out:
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
# DataFrame
# aghar ham kisi dataframe pa dropna method lagata han tu wo har row ko drop kardeta ha jis ma aik bhi missing value ho.
students.dropna()
# students.dropna(how="any") aik default parameter hota ha
# Out:
#       name college branch  cgpa  package
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0

# %%
# aghar hum chahta han ka sirf wo rows drop hon jisma all values missing ha tu phir hum (how="all") parameter use karaingy
students.dropna(how="all")
# Out:
#          name college branch   cgpa  package
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
# aghar hamma ksis column ki base pa drop karny ha koi row tu hum wo bhi karsakta han
students.dropna(subset=["name"])
# Out:
#          name college branch  cgpa  package
# 2      rupesh     vit    cse  6.41      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 0      nitish     bit    eee  6.66      4.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 1       ankit     iit     it  8.25      5.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
students.dropna(subset=["name","college"])
# Out:
#       name college branch  cgpa  package
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0

# %%
# fillna(Series+DataFrame)

# %%
# Series
students['package'] = students["package"].fillna(students['package'].mean())
students
# Out:
#          name college branch   cgpa   package
# 3         NaN     NaN    NaN    NaN  6.428571
# 5         NaN    vlsi     ce   9.00  7.000000
# 7         NaN     NaN    cse  10.00  9.000000
# 9         NaN     git    NaN    NaN  6.428571
# 2      rupesh     vit    cse   6.41  6.000000
# 6     rishabh    ssit    civ   7.40  8.000000
# 0      nitish     bit    eee   6.66  4.000000
# 4  mrityunjay     NaN     me   5.60  6.000000
# 1       ankit     iit     it   8.25  5.000000
# 8      aditya     NaN    bio   7.40  6.428571

# %%
# DataFrame
# ya prefer nahi kiya jaata ka hum fillna() ko datafram pa directly apply karain.hamma fillna() column pa apply karna chahiya 
students.fillna(0)
# Out:
#          name college branch   cgpa   package
# 3           0       0      0   0.00  6.428571
# 5           0    vlsi     ce   9.00  7.000000
# 7           0       0    cse  10.00  9.000000
# 9           0     git      0   0.00  6.428571
# 2      rupesh     vit    cse   6.41  6.000000
# 6     rishabh    ssit    civ   7.40  8.000000
# 0      nitish     bit    eee   6.66  4.000000
# 4  mrityunjay       0     me   5.60  6.000000
# 1       ankit     iit     it   8.25  5.000000
# 8      aditya       0    bio   7.40  6.428571

# %%
# drop_duplicates(Series+DataFrame)

# %%
# series
temp
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     2.0
# 7     3.0
# 8     4.0
# 9     4.0
# 10    3.0
# 11    2.0
# 12    5.0
# 13    5.0
# 14    6.0
# 15    6.0
# 16    NaN
# 17    NaN
# dtype: float64

# %%
temp.drop_duplicates()
# Out:
# 0     1.0
# 6     2.0
# 7     3.0
# 8     4.0
# 12    5.0
# 14    6.0
# 16    NaN
# dtype: float64

# %%
# DataFrame
st_marks = {
    'maths':[67,20,20],
    'english':[20,20,20],
    'science':[20,20,20],
    'hindi':[100,20,20]
}

marks_df = pd.DataFrame(st_marks)
marks_df
# Out:
#    maths  english  science  hindi
# 0     67       20       20    100
# 1     20       20       20     20
# 2     20       20       20     20

# %%
# keep="first" by default hota ha jho pehli occurence ko drop karta ha 
marks_df.drop_duplicates(keep="last")
# Out:
#    maths  english  science  hindi
# 0     67       20       20    100
# 2     20       20       20     20

# %%
# find the last match played by virat kohli in Delhi

# %%
ipl["all_players"] = ipl['Team1Players']+ipl["Team2Players"]

# %%
def did_kohli_play(players_list):
    return "V Kohli" in players_list

# %%
ipl["did_kohli_play"] = ipl["all_players"].apply(did_kohli_play)

# %%
values =["MatchNumber","Season","Team1","Team2","WinningTeam","Margin","City","Venue","Player_of_Match"]
ipl[(ipl["City"] == "Delhi") & (ipl["did_kohli_play"]) == True].drop_duplicates(subset=["City","did_kohli_play"])[values]
# Out:
#     MatchNumber Season           Team1                        Team2  \
# 208          46   2019  Delhi Capitals  Royal Challengers Bangalore
#
#         WinningTeam  Margin   City                 Venue Player_of_Match
# 208  Delhi Capitals    16.0  Delhi  Arun Jaitley Stadium        S Dhawan

# %%
# drop(Series+DataFrame)
# to drop the column/row from the dataframe

# %%
# Series
temp
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     2.0
# 7     3.0
# 8     4.0
# 9     4.0
# 10    3.0
# 11    2.0
# 12    5.0
# 13    5.0
# 14    6.0
# 15    6.0
# 16    NaN
# 17    NaN
# dtype: float64

# %%
temp.drop(index=[4,5,1,2,10,12,13])
# Out:
# 0     1.0
# 3     1.0
# 6     2.0
# 7     3.0
# 8     4.0
# 9     4.0
# 11    2.0
# 14    6.0
# 15    6.0
# 16    NaN
# 17    NaN
# dtype: float64

# %%
# DataFrame
students
# Out:
#          name college branch   cgpa   package
# 3         NaN     NaN    NaN    NaN  6.428571
# 5         NaN    vlsi     ce   9.00  7.000000
# 7         NaN     NaN    cse  10.00  9.000000
# 9         NaN     git    NaN    NaN  6.428571
# 2      rupesh     vit    cse   6.41  6.000000
# 6     rishabh    ssit    civ   7.40  8.000000
# 0      nitish     bit    eee   6.66  4.000000
# 4  mrityunjay     NaN     me   5.60  6.000000
# 1       ankit     iit     it   8.25  5.000000
# 8      aditya     NaN    bio   7.40  6.428571

# %%
students.drop(columns=["branch",'cgpa'])
# Out:
#          name college   package
# 3         NaN     NaN  6.428571
# 5         NaN    vlsi  7.000000
# 7         NaN     NaN  9.000000
# 9         NaN     git  6.428571
# 2      rupesh     vit  6.000000
# 6     rishabh    ssit  8.000000
# 0      nitish     bit  4.000000
# 4  mrityunjay     NaN  6.000000
# 1       ankit     iit  5.000000
# 8      aditya     NaN  6.428571

# %%
students.drop(index=[4,1,8])
# Out:
#       name college branch   cgpa   package
# 3      NaN     NaN    NaN    NaN  6.428571
# 5      NaN    vlsi     ce   9.00  7.000000
# 7      NaN     NaN    cse  10.00  9.000000
# 9      NaN     git    NaN    NaN  6.428571
# 2   rupesh     vit    cse   6.41  6.000000
# 6  rishabh    ssit    civ   7.40  8.000000
# 0   nitish     bit    eee   6.66  4.000000

# %%
# apply(Series+DataFrame)

# %%
# DataFrame
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def Euclidean(row):
    pt_A = row["1st point"]
    pt_B = row["2nd point"]
    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1]-pt_B[1])**2)**0.5

# %%
points_df["Euclidean_Distance"] = points_df.apply(Euclidean,axis=1)
points_df
# Out:
#   1st point 2nd point  Euclidean_Distance
# 0    (3, 4)   (-3, 4)            6.000000
# 1   (-6, 5)    (0, 0)            7.810250
# 2    (0, 0)    (2, 2)            2.828427
# 3  (-10, 1)  (10, 10)           21.931712
# 4    (4, 5)    (1, 1)            5.000000

# %%
# Remaining Part

# %%
# isin(Series)

# %%
# corr

# %%
# nlargest and nsmallest(Series and DataFrame)

# %%
# insert(DataFrame)

# %%
# copy(Series+DataFrame)
