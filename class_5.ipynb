# %%
# Groupby Function

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("imdb-top-1000.csv")
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
# groupby applies on categorical columns.

# %%
# groupby based on genre.
genres = movies.groupby("Genre")

# %%
# applying aggregate functions on groupby objects.

# %%
# we can apply all the aggregate function on groupby objects.
genres.sum(numeric_only=True)
# Out:
#            Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action       22196       1367.3     72282412  3.263226e+10    10499.0
# Adventure     9656        571.5     22576163  9.496922e+09     5020.0
# Animation     8166        650.3     21978630  1.463147e+10     6082.0
# Biography    11970        698.6     24006844  8.276358e+09     6023.0
# Comedy       17380       1224.7     27620327  1.566387e+10     9840.0
# Crime        13524        857.8     33533615  8.452632e+09     6706.0
# Drama        36049       2299.7     61367304  3.540997e+10    19208.0
# Family         215         15.6       551221  4.391106e+08      158.0
# Fantasy        170         16.0       146222  7.827267e+08        0.0
# Film-Noir      312         23.9       367215  1.259105e+08      287.0
# Horror        1123         87.0      3742556  1.034649e+09      880.0
# Mystery       1429         95.7      4203004  1.256417e+09      633.0
# ...

# %%
genres.std(numeric_only=True)
# Out:
#              Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     28.500706     0.304258  432946.814748  2.256724e+08  12.421252
# Adventure  33.317320     0.229781  301188.347642  1.697543e+08  12.345393
# Animation  14.530471     0.253221  262173.231571  2.091840e+08   8.813646
# Biography  25.514466     0.267140  271284.191372  1.363251e+08  11.028187
# Comedy     22.946213     0.228771  188653.570564  1.946513e+08  11.829160
# Crime      27.689231     0.335477  373999.730656  1.571191e+08  13.099102
# Drama      27.740490     0.267229  305554.162841  2.201164e+08  12.744687
# Family     10.606602     0.000000  137008.302816  3.048412e+08  16.970563
# Fantasy    12.727922     0.141421   22179.111299  7.606861e+07        NaN
# Film-Noir   4.000000     0.152753   54649.083277  7.048472e+07   1.527525
# Horror     13.604812     0.311302  234883.508691  9.965017e+07  15.362291
# Mystery    14.475423     0.310791  404621.915297  1.567524e+08  18.604435
# ...

# %%
genres.mean(numeric_only=True)
# Out:
#               Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419  420246.581395  1.897224e+08  73.419580
# Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.437500
# Animation   99.585366     7.930488  268032.073171  1.784326e+08  81.093333
# Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.240506
# Comedy     112.129032     7.901290  178195.658065  1.010572e+08  78.720000
# Crime      126.392523     8.016822  313398.271028  7.899656e+07  77.080460
# Drama      124.737024     7.957439  212343.612457  1.225259e+08  79.701245
# Family     107.500000     7.800000  275610.500000  2.195553e+08  79.000000
# Fantasy     85.000000     8.000000   73111.000000  3.913633e+08        NaN
# Film-Noir  104.000000     7.966667  122405.000000  4.197018e+07  95.666667
# Horror     102.090909     7.909091  340232.363636  9.405902e+07  80.000000
# ...

# %%
# find the top 3 genres by total earning

# %%
# movies.groupby("Genre").sum()["Gross"].sort_values(ascending=False).head(3)
# prefered code
movies.groupby("Genre")["Gross"].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# find the genre with  highest average imdb rating

# %%
movies.groupby("Genre")["IMDB_Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
# find director with most popularity(no.of votes)

# %%
movies.groupby("Director")["No_of_Votes"].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
# find the highest rated movie of each genre

# %%
# highest_rating_genre = movies.groupby("Genre")["IMDB_Rating"].max()
# highest_rating_genre

# %%
# find the no of movies done by each actor

# %%
# movies["Star1"].value_counts().head(1)
# movies.groupby("Star1")["Series_Title"].count().sort_values(ascending=False).head(1)
movies.groupby("Star1")["Series_Title"].nunique().sort_values(ascending=False).head(1)
# Out:
# Star1
# Tom Hanks    12
# Name: Series_Title, dtype: int64

# %%
# GroupBy Attributes and Methods
# find total number of groups -> len
# find items in each group -> size
# first()/last() -> nth item
# get_group -> vs filtering
# groups
# describe
# sample
# nunique

# %%
# find total number of groups -> len
genres = movies.groupby("Genre")
len(genres)
# Out:
# 14

# %%
movies["Genre"].nunique()
# Out:
# 14

# %%
# find items in each group -> size
genres.size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
movies["Genre"].value_counts()
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
# first()/last() -> nth item

# %%
genres.first()  #return first movie of each genre
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.last()  #return last movie of each genre
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
# want any movie from each genre
genres.nth(3)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 6                                         Pulp Fiction          1994      154
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 17                     One Flew Over the Cuckoo's Nest          1975      133
# 35                                    The Intouchables          2011      112
# 52                                         City Lights          1931       87
# 56                                      Kimi no na wa.          2016      106
# 110                                           Das Boot          1981      149
# 145                                     Shutter Island          2010      138
# 419                                       The Exorcist          1973      122
# 691                             The Outlaw Josey Wales          1976      135
#
#          Genre  IMDB_Rating           Director              Star1  \
# ...

# %%
# get_group()
genres.get_group("Western")
# Out:
#                         Series_Title Released_Year  Runtime    Genre  \
# 12   Il buono, il brutto, il cattivo          1966      161  Western
# 48      Once Upon a Time in the West          1968      165  Western
# 115       Per qualche dollaro in più          1965      132  Western
# 691           The Outlaw Josey Wales          1976      135  Western
#
#      IMDB_Rating        Director           Star1  No_of_Votes       Gross  \
# 12           8.8    Sergio Leone  Clint Eastwood       688390   6100000.0
# 48           8.5    Sergio Leone     Henry Fonda       302844   5321508.0
# 115          8.3    Sergio Leone  Clint Eastwood       232772  15000000.0
# 691          7.8  Clint Eastwood  Clint Eastwood        65659  31800000.0
#
#      Metascore
# 12        90.0
# 48        80.0
# 115       74.0
# 691       69.0

# %%
genres.get_group("Fantasy")
# Out:
#                      Series_Title Released_Year  Runtime    Genre  \
# 321  Das Cabinet des Dr. Caligari          1920       76  Fantasy
# 568                     Nosferatu          1922       94  Fantasy
#
#      IMDB_Rating      Director          Star1  No_of_Votes        Gross  \
# 321          8.1  Robert Wiene  Werner Krauss        57428  337574718.0
# 568          7.9   F.W. Murnau    Max Schreck        88794  445151978.0
#
#      Metascore
# 321        NaN
# 568        NaN

# %%
# groups
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# describe
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
# sample
genres.sample()
# Out:
#                                      Series_Title Released_Year  Runtime  \
# 944                               Batoru rowaiaru          2000      114
# 226  Harry Potter and the Deathly Hallows: Part 2          2011      130
# 595                                  Kaze tachinu          2013      126
# 212                                 Hacksaw Ridge          2016      139
# 316                         It Happened One Night          1934      105
# 827                             Miller's Crossing          1990      115
# 62                               Django Unchained          2012      165
# 698           Willy Wonka & the Chocolate Factory          1971      100
# 568                                     Nosferatu          1922       94
# 309                                 The Third Man          1949      104
# 876                             The Invisible Man          1933       71
# 69                                        Memento          2000      113
# ...

# %%
genres.sample(2,replace=True)
# Out:
#                                       Series_Title Released_Year  Runtime  \
# 5    The Lord of the Rings: The Return of the King          2003      201
# 648                            The Boondock Saints          1999      108
# 984                               The Muppet Movie          1979       95
# 755   Harry Potter and the Deathly Hallows: Part 1          2010      146
# 694                             La planète sauvage          1973       72
# 741                                Le Petit Prince          2015      108
# 897                                      Philomena          2013       98
# 157                                  Der Untergang          2004      156
# 704                                   Mary Poppins          1964      139
# 574                           Perfetti sconosciuti          2016       96
# 621                                          Drive          2011      100
# 926                               Dead Man's Shoes          2004       90
# ...

# %%
# nunique
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
# agg function 
# aghar hum chahta ka kisi column pa mean lagay or kisi pam sum.

# %%
genres.sum(numeric_only=True)
# Out:
#            Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action       22196       1367.3     72282412  3.263226e+10    10499.0
# Adventure     9656        571.5     22576163  9.496922e+09     5020.0
# Animation     8166        650.3     21978630  1.463147e+10     6082.0
# Biography    11970        698.6     24006844  8.276358e+09     6023.0
# Comedy       17380       1224.7     27620327  1.566387e+10     9840.0
# Crime        13524        857.8     33533615  8.452632e+09     6706.0
# Drama        36049       2299.7     61367304  3.540997e+10    19208.0
# Family         215         15.6       551221  4.391106e+08      158.0
# Fantasy        170         16.0       146222  7.827267e+08        0.0
# Film-Noir      312         23.9       367215  1.259105e+08      287.0
# Horror        1123         87.0      3742556  1.034649e+09      880.0
# Mystery       1429         95.7      4203004  1.256417e+09      633.0
# ...

# %%
genres.agg(
    {
        "Runtime":"mean",
        "IMDB_Rating":"mean",
        "No_of_Votes":"sum",
        "Gross":"sum",
        "Metascore":"mean"
    }
)
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10  73.419580
# Adventure  134.111111     7.937500     22576163  9.496922e+09  78.437500
# Animation   99.585366     7.930488     21978630  1.463147e+10  81.093333
# Biography  136.022727     7.938636     24006844  8.276358e+09  76.240506
# Comedy     112.129032     7.901290     27620327  1.566387e+10  78.720000
# Crime      126.392523     8.016822     33533615  8.452632e+09  77.080460
# Drama      124.737024     7.957439     61367304  3.540997e+10  79.701245
# Family     107.500000     7.800000       551221  4.391106e+08  79.000000
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08  95.666667
# Horror     102.090909     7.909091      3742556  1.034649e+09  80.000000
# Mystery    119.083333     7.975000      4203004  1.256417e+09  79.125000
# ...

# %%
# here we use select_dtype method for filtering .
numeric_columns = movies.select_dtypes(include='number').columns[[0,1,2]]
# numeric_columns
genres[numeric_columns].agg(['mean', 'max', 'min', 'sum'])
# Out:
#               Runtime                  IMDB_Rating                    \
#                  mean  max  min    sum        mean  max  min     sum
# Genre
# Action     129.046512  321   45  22196    7.949419  9.0  7.6  1367.3
# Adventure  134.111111  228   88   9656    7.937500  8.6  7.6   571.5
# Animation   99.585366  137   71   8166    7.930488  8.6  7.6   650.3
# Biography  136.022727  209   93  11970    7.938636  8.9  7.6   698.6
# Comedy     112.129032  188   68  17380    7.901290  8.6  7.6  1224.7
# Crime      126.392523  229   80  13524    8.016822  9.2  7.6   857.8
# Drama      124.737024  242   64  36049    7.957439  9.3  7.6  2299.7
# Family     107.500000  115  100    215    7.800000  7.8  7.8    15.6
# Fantasy     85.000000   94   76    170    8.000000  8.1  7.9    16.0
# Film-Noir  104.000000  108  100    312    7.966667  8.1  7.8    23.9
# Horror     102.090909  122   71   1123    7.909091  8.5  7.6    87.0
# ...

# %%
# looping on groups

# %%
# find the highest rated movie of each genre.

# %%
rows = []
for groups,data in genres:
    max_rating = data["IMDB_Rating"].max()
    # print(max_rating)
    max_rating_row = data[data["IMDB_Rating"] == max_rating]
    rows.append(max_rating_row)
# print(type(rows))
res = pd.concat(rows,ignore_index=True)
res
# Out:
#                            Series_Title Released_Year  Runtime      Genre  \
# 0                       The Dark Knight          2008      152     Action
# 1                          Interstellar          2014      169  Adventure
# 2         Sen to Chihiro no kamikakushi          2001      125  Animation
# 3                      Schindler's List          1993      195  Biography
# 4                          Gisaengchung          2019      132     Comedy
# 5                       La vita è bella          1997      116     Comedy
# 6                         The Godfather          1972      175      Crime
# 7              The Shawshank Redemption          1994      142      Drama
# 8            E.T. the Extra-Terrestrial          1982      115     Family
# 9   Willy Wonka & the Chocolate Factory          1971      100     Family
# 10         Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 11                        The Third Man          1949      104  Film-Noir
# ...

# %%
# Group by 'Genre' and find the index of the highest rated movie in each genre
max_rating_indices = genres['IMDB_Rating'].idxmax()
highest_rated = movies.loc[max_rating_indices,["Series_Title","Genre","Released_Year"]]
highest_rated
# Out:
#                         Series_Title      Genre Released_Year
# 2                    The Dark Knight     Action          2008
# 21                      Interstellar  Adventure          2014
# 23     Sen to Chihiro no kamikakushi  Animation          2001
# 7                   Schindler's List  Biography          1993
# 19                      Gisaengchung     Comedy          2019
# 1                      The Godfather      Crime          1972
# 0           The Shawshank Redemption      Drama          1994
# 688       E.T. the Extra-Terrestrial     Family          1982
# 321     Das Cabinet des Dr. Caligari    Fantasy          1920
# 309                    The Third Man  Film-Noir          1949
# 49                            Psycho     Horror          1960
# 69                           Memento    Mystery          2000
# 700                  Wait Until Dark   Thriller          1967
# 12   Il buono, il brutto, il cattivo    Western          1966

# %%
# find the number of movies starting with A for each group

# %%
# "apply" works on three stages
# split--apply--combine

# %%
genres["Series_Title"].apply(lambda x : x.str.startswith('A').sum())
# Out:
# Genre
# Action       10
# Adventure     2
# Animation     2
# Biography     9
# Comedy       14
# Crime         4
# Drama        21
# Family        0
# Fantasy       0
# Film-Noir     0
# Horror        1
# Mystery       0
# Thriller      0
# Western       0
# Name: Series_Title, dtype: int64

# %%
# find ranking of each movie in the group according to IMDB score.

# %%
def rank_each_movie(group):
    group["Ranking"] = group["IMDB_Rating"].rank(ascending=False)
    return group

# %%
genres.apply(rank_each_movie)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2680\1262545758.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(rank_each_movie)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
# find normalized IMDB rating group wise

# %%
def normalized_rating(group):
    group["Noramlized_Rating"] = group["IMDB_Rating"]-group["IMDB_Rating"].min()/group["IMDB_Rating"].max()-group["IMDB_Rating"].min()
    return group

# %%
genres.apply(normalized_rating)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2680\1442021306.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(normalized_rating)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
# groupby on multiple columns
# size
# get_group()

# %%
duo = movies.groupby(["Director","Star1"])
duo

# %%
duo.size()
# Out:
# Director             Star1
# Aamir Khan           Amole Gupte       1
# Aaron Sorkin         Eddie Redmayne    1
# Abdellatif Kechiche  Léa Seydoux       1
# Abhishek Chaubey     Shahid Kapoor     1
# Abhishek Kapoor      Amit Sadh         1
#                                       ..
# Zaza Urushadze       Lembit Ulfsak     1
# Zoya Akhtar          Hrithik Roshan    1
#                      Vijay Varma       1
# Çagan Irmak          Çetin Tekindor    1
# Ömer Faruk Sorak     Cem Yilmaz        1
# Length: 898, dtype: int64

# %%
duo.get_group(("Aamir Khan","Amole Gupte"))
# Out:
#         Series_Title Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 65  Taare Zameen Par          2007      165  Drama          8.4  Aamir Khan
#
#           Star1  No_of_Votes      Gross  Metascore
# 65  Amole Gupte       168895  1223869.0        NaN

# %%
# find the most earning (actor,Director)-->combo

# %%
duo['Gross'].sum().sort_values(ascending=False).head(1)
# Out:
# Director        Star1
# Akira Kurosawa  Toshirô Mifune    2.999877e+09
# Name: Gross, dtype: float64

# %%
# find the best(in terms of metascore(avg)) (actor and genre)-->combo

# %%
actor_genre = movies.groupby(["Star1","Genre"])
# Here we use "reset_index" to convert (series into DataFrame)
actor_genre["Metascore"].mean().reset_index().sort_values("Metascore",ascending=False).head(1)
# Out:
#               Star1  Genre  Metascore
# 230  Ellar Coltrane  Drama      100.0

# %%
# agg on multiple groupby

# %%
numeric_columns = movies.select_dtypes(include="number").columns
duo[numeric_columns].agg(["mean","max","min"])
# Out:
#                                    Runtime           IMDB_Rating            \
#                                       mean  max  min        mean  max  min
# Director            Star1
# Aamir Khan          Amole Gupte      165.0  165  165         8.4  8.4  8.4
# Aaron Sorkin        Eddie Redmayne   129.0  129  129         7.8  7.8  7.8
# Abdellatif Kechiche Léa Seydoux      180.0  180  180         7.7  7.7  7.7
# Abhishek Chaubey    Shahid Kapoor    148.0  148  148         7.8  7.8  7.8
# Abhishek Kapoor     Amit Sadh        130.0  130  130         7.7  7.7  7.7
# ...                                    ...  ...  ...         ...  ...  ...
# Zaza Urushadze      Lembit Ulfsak     87.0   87   87         8.2  8.2  8.2
# Zoya Akhtar         Hrithik Roshan   155.0  155  155         8.1  8.1  8.1
#                     Vijay Varma      154.0  154  154         8.0  8.0  8.0
# Çagan Irmak         Çetin Tekindor   112.0  112  112         8.3  8.3  8.3
# ...

# %%
# IPL Dataset
ipl = pd.read_csv("deliveries.csv")
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
ipl.shape
# Out:
# (179078, 21)

# %%
# find the top 10 batsman in terms of runs
batsman = ipl.groupby("batsman")
# here we use reset_index() to convert the (series into DataFrame)
batsman["batsman_runs"].sum().sort_values(ascending=False).reset_index().head(10)
# Out:
#           batsman  batsman_runs
# 0         V Kohli          5434
# 1        SK Raina          5415
# 2       RG Sharma          4914
# 3       DA Warner          4741
# 4        S Dhawan          4632
# 5        CH Gayle          4560
# 6        MS Dhoni          4477
# 7      RV Uthappa          4446
# 8  AB de Villiers          4428
# 9       G Gambhir          4223

# %%
# find the batsman with max no of sixes
six = ipl[ipl["batsman_runs"] == 6]
batsman_hit_six = six.groupby("batsman")
# batsman_hit_six.count().sort_values("batsman_runs",ascending=False)["batsman_runs"].head(1).index[0]  #not prefer
# Another way
batsman_hit_six["batsman"].count().sort_values(ascending=False).head(1).index[0]
# Out:
# 'CH Gayle'

# %%
# find batsman with most number of 4's and 6's in last 5 overs
over_above_15_df = ipl[ipl["over"] > 15]
batsman_with_6_or_4 = over_above_15_df[(over_above_15_df["batsman_runs"] == 4) | (over_above_15_df["batsman_runs"] == 6)]
batsman_with_6_or_4.groupby("batsman")["batsman"].count().sort_values(ascending=False).head(1)
# Out:
# batsman
# MS Dhoni    340
# Name: batsman, dtype: int64

# %%
# find V Kohli's record against all teams
def kohli_record(group):
    spec_col = group.agg(
        {
            "batsman_runs":"sum",
            "legbye_runs":"sum"
        }
    )
    return spec_col

# %%
batsman_Kohli = ipl[ipl["batsman"] == "V Kohli"]
bowling_team = batsman_Kohli.groupby("bowling_team")
batsman_runs_and_legbye_runs_df = bowling_team.apply(kohli_record)
batsman_runs_and_legbye_runs_df
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2680\3263981042.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batsman_runs_and_legbye_runs_df = bowling_team.apply(kohli_record)
#                          batsman_runs  legbye_runs
# bowling_team
# Chennai Super Kings               749            8
# Deccan Chargers                   306            4
# Delhi Capitals                     66            2
# Delhi Daredevils                  763           11
# Gujarat Lions                     283            1
# Kings XI Punjab                   636            3
# Kochi Tuskers Kerala               50            0
# Kolkata Knight Riders             675            6
# ...

# %%
batsman_runs_and_legbye_runs_df.plot(kind="bar",color=["green","red"])
# Out:
# <Axes: xlabel='bowling_team'>

# %%
# Add some more records

# %%
kohli_4 = ipl[(ipl["batsman_runs"] == 4) & (ipl["batsman"] == "V Kohli")]
kohli_6 = ipl[(ipl["batsman_runs"] == 6) & (ipl["batsman"] == "V Kohli")]
fours_by_kohli = kohli_4.groupby("bowling_team")
sixes_by_kohli = kohli_6.groupby("bowling_team")

# %%
four_df = fours_by_kohli["batsman_runs"].count().reset_index()
sixes_df = sixes_by_kohli["batsman_runs"].count().reset_index()

# %%
# Renaming the columns
four_df.rename(columns={"batsman_runs":"No_of_Fours"},inplace=True)
sixes_df.rename(columns={"batsman_runs":"No_of_Sixes"},inplace=True)

# %%
# concate two dataframes
four_and_sixes = pd.concat([four_df,sixes_df],axis=1)
# removing duplicate columns
four_and_sixes_df = four_and_sixes.loc[:,~four_and_sixes.columns.duplicated()]
four_and_sixes_df.set_index("bowling_team",inplace=True)

# %%
kohli_records_against_all_teams_df = pd.concat([four_and_sixes_df,batsman_runs_and_legbye_runs_df],axis=1)
kohli_records_against_all_teams_df
# Out:
#                          No_of_Fours  No_of_Sixes  batsman_runs  legbye_runs
# bowling_team
# Chennai Super Kings               57         30.0           749            8
# Deccan Chargers                   23         14.0           306            4
# Delhi Capitals                     3          3.0            66            2
# Delhi Daredevils                  74         22.0           763           11
# Gujarat Lions                     24         11.0           283            1
# Kings XI Punjab                   74         18.0           636            3
# Kochi Tuskers Kerala               7         22.0            50            0
# Kolkata Knight Riders             58         24.0           675            6
# Mumbai Indians                    52          5.0           628            5
# Pune Warriors                      9         10.0           128            0
# Rajasthan Royals                  29          2.0           370            4
# ...

# %%
# plotting
ax = kohli_records_against_all_teams_df.plot(kind='bar', figsize=(10, 6))
ax.set_xlabel("Teams")
ax.set_ylabel("Counts")
ax.set_title("Virat Kohli Record Against All Ipl Teams")
# Out:
# Text(0.5, 1.0, 'Virat Kohli Record Against All Ipl Teams')

# %%
# Create a function that can return the total runs of any batsman

# %%
def batsman_total_runs(batsman_name):
    highest_runs = ipl.groupby("batsman").get_group(batsman_name)["batsman_runs"].sum()
    print(f"{batsman_name} total runs are {highest_runs}")

# %%
batsman_total_runs("V Kohli")
# Out:
# V Kohli total runs are 5434

# %%
# Create a function that can return the highest score of any batsman.

# %%
def batsman_highest_runs(batsman_name):
    temp = ipl[ipl["batsman"] == batsman_name]
    res = temp.groupby("match_id")["batsman_runs"].sum().sort_values(ascending=False).head(1).values[0]
    print(f"highest runs of {batsman_name} is {res}")

# %%
batsman_highest_runs("CH Gayle")
# Out:
# highest runs of CH Gayle is 175
